# %%
get_ipython().run_line_magic('matplotlib', 'inline')
import os

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import random
import pickle

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve

import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv(r"/content/drive/MyDrive/brain_stroke.csv")
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4976          Rural              70.15  29.8  formerly smoked       0
# 4977          Urban             191.15  31.1           smokes       0
# 4978          Rural              95.02  31.8           smokes       0
# 4979          Rural              83.94  30.0           smokes       0
# 4980          Urban              83.75  29.1     never smoked       0
#
# [4981 rows x 11 columns]

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['gender', 'age', 'hypertension', 'heart_disease', 'ever_married', 'work_type', 'Residence_type', 'avg_glucose_level', 'bmi', 'smoking_status', 'stroke']

# %% [markdown]
# 1) gender: "Male", "Female" or "Other"
#
# 2) age: age of the patient
#
# 3) hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension
#
# 4) heart disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease 5) Ever-married: "No" or "Yes"
#
# 6) work type: "children", "Govtjov", "Never worked", "Private" or "Self-employed"
#
# 7) Residencetype: "Rural" or "Urban"
#
# 8) avg glucose level: average glucose level in blood
#
# 9) BMI: body mass index
#
# 10) smoking_status: "formerly smoked", "never smoked", "smokes" or "Unknown"*
#
# 11) stroke: 1 if the patient had a stroke or 0 if not

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %%
df["stroke"].value_counts()
# Out:
# stroke
# 0    4733
# 1     248
# Name: count, dtype: int64

# %%
from sklearn.utils import resample
# Separate majority and minority classes
# Converting 'stroke' to numeric before filtering
df['stroke'] = pd.to_numeric(df['stroke'], errors='coerce')

df_majority = df[df['stroke'] == 0]
df_minority = df[df['stroke'] == 1]

# Downsample majority class and upsample the minority class
df_minority_upsampled = resample(df_minority, replace=True, n_samples=4000, random_state=100)
df_majority_downsampled = resample(df_majority, replace=True, n_samples=4000, random_state=100)

# Combine minority class with downsampled majority class
df_balanced = pd.concat([df_minority_upsampled, df_majority_downsampled])

# Display new class counts
df_balanced['stroke'].value_counts()
# Out:
# stroke
# 1    4000
# 0    4000
# Name: count, dtype: int64

# %%
df = df_balanced

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Initialize the label encoder
le = LabelEncoder()

# List of columns that are of type 'object' (categorical features)
object_cols = df.select_dtypes(include=['object']).columns

# Convert all object-type columns to string (to handle mixed types)
for col in object_cols:
    df[col] = df[col].astype(str)  # Ensure all data in the column is treated as string

# Apply label encoding to each object-type column
for col in object_cols:
    df[col] = le.fit_transform(df[col])

# Check the result (first few rows)
print(df.head())
# Out:
#      gender   age  hypertension  heart_disease  ever_married  work_type  \
# 8         0  81.0             1              0             1          1
# 24        1  57.0             1              0             1          1
# 67        0  68.0             1              0             0          2
# 103       1  56.0             1              0             1          1
# 87        0  57.0             0              0             1          0
#
#      Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 8                 0              80.43  29.7               2       1
# 24                1             212.08  44.2               3       1
# 67                1              79.79  29.7               2       1
# 103               0             249.31  35.8               2       1
# 87                1             110.52  28.5               0       1

# %%
df.corr()
# Out:
#                      gender       age  hypertension  heart_disease  \
# gender             1.000000  0.025080      0.009527       0.132434
# age                0.025080  1.000000      0.264137       0.267060
# hypertension       0.009527  0.264137      1.000000       0.083510
# heart_disease      0.132434  0.267060      0.083510       1.000000
# ever_married       0.041141  0.557315      0.087717       0.066755
# work_type          0.040746 -0.287421     -0.003522      -0.063355
# Residence_type    -0.009660  0.018222     -0.007367       0.025359
# avg_glucose_level  0.118891  0.275511      0.146584       0.260343
# bmi                0.020626  0.236305      0.101440       0.063601
# smoking_status    -0.043118  0.184728      0.140752       0.090577
# stroke             0.024580  0.569862      0.221618       0.214740
#
#                    ever_married  work_type  Residence_type  avg_glucose_level  \
# gender                 0.041141   0.040746       -0.009660           0.118891
# age                    0.557315  -0.287421        0.018222           0.275511
# hypertension           0.087717  -0.003522       -0.007367           0.146584
# heart_disease          0.066755  -0.063355        0.025359           0.260343
# ever_married           1.000000  -0.295554       -0.047859           0.191441
# work_type             -0.295554   1.000000        0.013016          -0.114675
# Residence_type        -0.047859   0.013016        1.000000           0.031880
# avg_glucose_level      0.191441  -0.114675        0.031880           1.000000
# bmi                    0.294804  -0.268897        0.007853           0.268539
# smoking_status         0.195406  -0.225640       -0.021407           0.077403
# stroke                 0.280766  -0.104454        0.031315           0.250170
#
#                         bmi  smoking_status    stroke
# gender             0.020626       -0.043118  0.024580
# age                0.236305        0.184728  0.569862
# hypertension       0.101440        0.140752  0.221618
# heart_disease      0.063601        0.090577  0.214740
# ever_married       0.294804        0.195406  0.280766
# work_type         -0.268897       -0.225640 -0.104454
# Residence_type     0.007853       -0.021407  0.031315
# avg_glucose_level  0.268539        0.077403  0.250170
# bmi                1.000000        0.164174  0.136838
# smoking_status     0.164174        1.000000  0.060221
# stroke             0.136838        0.060221  1.000000

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True)
plt.title('Heatmap of Correlations',fontsize=15)
plt.show()

# %%
x = df.drop(columns=['stroke'])
y = df['stroke']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=100)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train.shape
# Out:
# (6000, 10)

# %%
import numpy as np

# Reshape the data for CNN
x_train_cnn = np.expand_dims(x_train, axis=2)  # Adding a channel dimension
x_test_cnn = np.expand_dims(x_test, axis=2)

# %%
# First lets add the necessary import for Label Encoding the y values
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.preprocessing import LabelEncoder

# Define the CNN model
def build_cnn_model(input_shape):
    model = Sequential([
        Conv1D(64, kernel_size=3, activation='relu', padding='same', input_shape=input_shape), #Added padding='same'
        MaxPooling1D(pool_size=2),
        Conv1D(32, kernel_size=3, activation='relu', padding='same'), #Added padding='same'
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')  # For binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Encode the y values
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# Build the model
cnn_model = build_cnn_model((x_train_cnn.shape[1], 1))

import pickle
pickle.dump(cnn_model, open(r'/content/cnn.pkl', 'wb'))

#Print the summary after the model has been made
print(cnn_model.summary())

# Train the model
history_cnn = cnn_model.fit(x_train_cnn, y_train, validation_split=0.2, epochs=100, batch_size=32)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None,
# Epoch 74/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9613 - loss: 0.1086 - val_accuracy: 0.9450 - val_loss: 0.2130
# Epoch 75/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9619 - loss: 0.1125 - val_accuracy: 0.9358 - val_loss: 0.2128
# Epoch 76/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9565 - loss: 0.1270 - val_accuracy: 0.9483 - val_loss: 0.1936
# Epoch 77/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9600 - loss: 0.1126 - val_accuracy: 0.9300 - val_loss: 0.2181
# Epoch 78/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9579 - loss: 0.1204 - val_accuracy: 0.9492 - val_loss: 0.1757
# Epoch 79/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9630 - loss: 0.1101 - val_accuracy: 0.9283 - val_loss: 0.2231
# Epoch 80/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9582 - loss: 0.1160 - val_accuracy: 0.9433 - val_loss: 0.1794
# Epoch 81/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9661 - loss: 0.0981 - val_accuracy: 0.9467 - val_loss: 0.1899
# Epoch 82/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9679 - loss: 0.0989 - val_accuracy: 0.9525 - val_loss: 0.1641
# Epoch 83/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9630 - loss: 0.1034 - val_accuracy: 0.9450 - val_loss: 0.1792
# Epoch 84/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9638 - loss: 0.1073 - val_accuracy: 0.9458 - val_loss: 0.1832
# Epoch 85/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9637 - loss: 0.0958 - val_accuracy: 0.9408 - val_loss: 0.1802
# Epoch 86/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9695 - loss: 0.0870 - val_accuracy: 0.9458 - val_loss: 0.1904
# Epoch 87/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9622 - loss: 0.1056 - val_accuracy: 0.9542 - val_loss: 0.1696
# Epoch 88/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9586 - loss: 0.1226 - val_accuracy: 0.9400 - val_loss: 0.1935
# Epoch 89/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9664 - loss: 0.0953 - val_accuracy: 0.9433 - val_loss: 0.2120
# Epoch 90/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9668 - loss: 0.1002 - val_accuracy: 0.9408 - val_loss: 0.1984
# Epoch 91/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9670 - loss: 0.1017 - val_accuracy: 0.9408 - val_loss: 0.1779
# Epoch 92/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9725 - loss: 0.0889 - val_accuracy: 0.9383 - val_loss: 0.2255
# Epoch 93/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9696 - loss: 0.0897 - val_accuracy: 0.9450 - val_loss: 0.1767
# Epoch 94/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9725 - loss: 0.0800 - val_accuracy: 0.9558 - val_loss: 0.1691
# Epoch 95/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9693 - loss: 0.0879 - val_accuracy: 0.9508 - val_loss: 0.1878
# Epoch 96/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9758 - loss: 0.0770 - val_accuracy: 0.9483 - val_loss: 0.1707
# Epoch 97/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9760 - loss: 0.0725 - val_accuracy: 0.9358 - val_loss: 0.1894
# Epoch 98/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9681 - loss: 0.0889 - val_accuracy: 0.9442 - val_loss: 0.1952
# Epoch 99/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9691 - loss: 0.0817 - val_accuracy: 0.9433 - val_loss: 0.1860
# Epoch 100/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9726 - loss: 0.0818 - val_accuracy: 0.9442 - val_loss: 0.1724

# %%
# Evaluate on test data
cnn_loss, cnn_accuracy = cnn_model.evaluate(x_test_cnn, y_test)
print(f"Test Loss: {cnn_loss:.4f}, Test Accuracy: {cnn_accuracy:.4f}")

# Make predictions
cnn_predictions = (cnn_model.predict(x_test_cnn) > 0.5).astype(int)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9515 - loss: 0.1609
# Test Loss: 0.1498, Test Accuracy: 0.9530
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history_cnn.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn.history['val_accuracy'], label='Validation Accuracy')
plt.title('CNN Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot training & validation loss
plt.plot(history_cnn.history['loss'], label='Train Loss')
plt.plot(history_cnn.history['val_loss'], label='Validation Loss')
plt.title('CNN Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Confusion matrix
cm = confusion_matrix(y_test, cnn_predictions)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('CNN Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification report
print(classification_report(y_test, cnn_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.91      0.95      1016
#            1       0.92      0.99      0.95       984
#
#     accuracy                           0.95      2000
#    macro avg       0.96      0.95      0.95      2000
# weighted avg       0.96      0.95      0.95      2000

# %%
# Reshape the data for LSTM
x_train_lstm = np.expand_dims(x_train, axis=1)  # Adding a timestep dimension
x_test_lstm = np.expand_dims(x_test, axis=1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Define the LSTM model
def build_lstm_model(input_shape):
    model = Sequential([
        LSTM(128, activation='tanh', return_sequences=True, input_shape=input_shape),
        Dropout(0.3),
        LSTM(64, activation='tanh'),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')  # For binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

#
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8366 - loss: 0.3455 - val_accuracy: 0.8042 - val_loss: 0.4086
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8299 - loss: 0.3655 - val_accuracy: 0.8142 - val_loss: 0.4057
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8326 - loss: 0.3661 - val_accuracy: 0.8142 - val_loss: 0.4013
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8424 - loss: 0.3539 - val_accuracy: 0.8092 - val_loss: 0.3989
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8455 - loss: 0.3475 - val_accuracy: 0.8083 - val_loss: 0.3993
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8406 - loss: 0.3438 - val_accuracy: 0.8142 - val_loss: 0.3894
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8401 - loss: 0.3435 - val_accuracy: 0.8142 - val_loss: 0.3900
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8425 - loss: 0.3535 - val_accuracy: 0.8200 - val_loss: 0.3968
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8391 - loss: 0.3512 - val_accuracy: 0.8150 - val_loss: 0.3905
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8478 - loss: 0.3303 - val_accuracy: 0.8200 - val_loss: 0.3867
# Epoch 44/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8454 - loss: 0.3375 - val_accuracy: 0.8350 - val_loss: 0.3845
# Epoch 45/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8443 - loss: 0.3374 - val_accuracy: 0.8308 - val_loss: 0.3778
# Epoch 46/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8487 - loss: 0.3294 - val_accuracy: 0.8300 - val_loss: 0.3806
# Epoch 47/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8465 - loss: 0.3355 - val_accuracy: 0.8350 - val_loss: 0.3780
# Epoch 48/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8524 - loss: 0.3317 - val_accuracy: 0.8308 - val_loss: 0.3757
# Epoch 49/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8528 - loss: 0.3298 - val_accuracy: 0.8408 - val_loss: 0.3776
# Epoch 50/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8499 - loss: 0.3324 - val_accuracy: 0.8358 - val_loss: 0.3804

# %%
# Evaluate on test data
lstm_loss, lstm_accuracy = lstm_model.evaluate(x_test_lstm, y_test)
print(f"Test Loss: {lstm_loss:.4f}, Test Accuracy: {lstm_accuracy:.4f}")

# Make predictions
lstm_predictions = (lstm_model.predict(x_test_lstm) > 0.5).astype(int)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8384 - loss: 0.3490
# Test Loss: 0.3463, Test Accuracy: 0.8470
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
import pickle
pickle.dump(lstm_model, open(r'/content/lstm.pkl', 'wb'))

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history_lstm.history['accuracy'], label='Train Accuracy')
plt.plot(history_lstm.history['val_accuracy'], label='Validation Accuracy')
plt.title('LSTM Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot training & validation loss
plt.plot(history_lstm.history['loss'], label='Train Loss')
plt.plot(history_lstm.history['val_loss'], label='Validation Loss')
plt.title('LSTM Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Confusion matrix
cm = confusion_matrix(y_test, lstm_predictions)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('LSTM Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification report
print(classification_report(y_test, lstm_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84      1016
#            1       0.81      0.90      0.85       984
#
#     accuracy                           0.85      2000
#    macro avg       0.85      0.85      0.85      2000
# weighted avg       0.85      0.85      0.85      2000

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Flatten, Dense, Dropout, Reshape
from sklearn.preprocessing import LabelEncoder

# Define the CNN-LSTM model
def build_cnn_lstm_model(input_shape):
    model = Sequential([
        Conv1D(64, kernel_size=3, activation='relu', padding='same', input_shape=input_shape),
        MaxPooling1D(pool_size=2),
        Conv1D(32, kernel_size=3, activation='relu', padding='same'),
        MaxPooling1D(pool_size=2),
        Reshape((input_shape[0] // 4, 32)),  # Adjust dimensions for LSTM
        LSTM(50, return_sequences=False),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')  # For binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Encode the y values
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# Build the model
cnn_lstm_model = build_cnn_lstm_model((x_train_cnn.shape[1], 1))

# Print the summary after the model has been made
print(cnn_lstm_model.summary())

# Train the model
history_cnn_lstm = cnn_lstm_model.fit(x_train_cnn, y_train, validation_split=0.2, epochs=100, batch_size=32)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)                    │ (None, 10, 64)              │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_2 (MaxPooling1D)       │ (None,
# Epoch 73/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9678 - loss: 0.0883 - val_accuracy: 0.9458 - val_loss: 0.2223
# Epoch 74/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9719 - loss: 0.0749 - val_accuracy: 0.9558 - val_loss: 0.2417
# Epoch 75/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9774 - loss: 0.0579 - val_accuracy: 0.9333 - val_loss: 0.2916
# Epoch 76/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9671 - loss: 0.0872 - val_accuracy: 0.9458 - val_loss: 0.2942
# Epoch 77/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9746 - loss: 0.0682 - val_accuracy: 0.9550 - val_loss: 0.2445
# Epoch 78/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9814 - loss: 0.0513 - val_accuracy: 0.9308 - val_loss: 0.2985
# Epoch 79/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9664 - loss: 0.0977 - val_accuracy: 0.9425 - val_loss: 0.2573
# Epoch 80/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9720 - loss: 0.0716 - val_accuracy: 0.9517 - val_loss: 0.2311
# Epoch 81/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9850 - loss: 0.0465 - val_accuracy: 0.9575 - val_loss: 0.1789
# Epoch 82/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9836 - loss: 0.0461 - val_accuracy: 0.9458 - val_loss: 0.2168
# Epoch 83/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9832 - loss: 0.0528 - val_accuracy: 0.9217 - val_loss: 0.3093
# Epoch 84/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9790 - loss: 0.0584 - val_accuracy: 0.9583 - val_loss: 0.2397
# Epoch 85/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9827 - loss: 0.0514 - val_accuracy: 0.9600 - val_loss: 0.2247
# Epoch 86/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9844 - loss: 0.0415 - val_accuracy: 0.9542 - val_loss: 0.2539
# Epoch 87/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9843 - loss: 0.0500 - val_accuracy: 0.9567 - val_loss: 0.2345
# Epoch 88/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9847 - loss: 0.0438 - val_accuracy: 0.9367 - val_loss: 0.3627
# Epoch 89/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9713 - loss: 0.0770 - val_accuracy: 0.9325 - val_loss: 0.3248
# Epoch 90/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9711 - loss: 0.0914 - val_accuracy: 0.9525 - val_loss: 0.2666
# Epoch 91/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9884 - loss: 0.0434 - val_accuracy: 0.9533 - val_loss: 0.2190
# Epoch 92/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9870 - loss: 0.0389 - val_accuracy: 0.9492 - val_loss: 0.2324
# Epoch 93/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9831 - loss: 0.0499 - val_accuracy: 0.9492 - val_loss: 0.2855
# Epoch 94/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9841 - loss: 0.0482 - val_accuracy: 0.9350 - val_loss: 0.2737
# Epoch 95/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9712 - loss: 0.0732 - val_accuracy: 0.9417 - val_loss: 0.2291
# Epoch 96/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9782 - loss: 0.0641 - val_accuracy: 0.9558 - val_loss: 0.2003
# Epoch 97/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9839 - loss: 0.0486 - val_accuracy: 0.9567 - val_loss: 0.2183
# Epoch 98/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9879 - loss: 0.0375 - val_accuracy: 0.9583 - val_loss: 0.2360
# Epoch 99/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9799 - loss: 0.0571 - val_accuracy: 0.9550 - val_loss: 0.2344
# Epoch 100/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9811 - loss: 0.0489 - val_accuracy: 0.9400 - val_loss: 0.2578

# %%
# Evaluate the model on test data
test_loss, test_accuracy = cnn_lstm_model.evaluate(x_test_cnn, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9332 - loss: 0.2618
# Test Accuracy: 93.60%

# %%
import pickle
pickle.dump(cnn_lstm_model, open(r'/content/cnn_lstm.pkl', 'wb'))

# %%
# Plot accuracy curves
plt.figure(figsize=(8, 6))
plt.plot(history_cnn_lstm.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn_lstm.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
# Plot loss curves
plt.figure(figsize=(8, 6))
plt.plot(history_cnn_lstm.history['loss'], label='Train Loss')
plt.plot(history_cnn_lstm.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
# Generate confusion matrix
y_pred = cnn_lstm_model.predict(x_test_cnn)
y_pred_classes = (y_pred > 0.5).astype(int)
cm = confusion_matrix(y_test, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
